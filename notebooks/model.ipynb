# %%
# %pip install transformers torch ipywidgets huggingface_hub[hf_xet]

# %%
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("indolem/indobert-base-uncased")
model = AutoModel.from_pretrained("indolem/indobert-base-uncased")
# Out:
# model.safetensors:   0%|          | 0.00/445M [00:00<?, ?B/s]

# %%
model.save_pretrained("models/saved/indobert-local")
tokenizer.save_pretrained("models/saved/indobert-local")
# Out:
# ('models/saved/indobert-local\\tokenizer_config.json',
#  'models/saved/indobert-local\\special_tokens_map.json',
#  'models/saved/indobert-local\\vocab.txt',
#  'models/saved/indobert-local\\added_tokens.json',
#  'models/saved/indobert-local\\tokenizer.json')
